# %% [markdown]
# ## What is literal?

# %%
# variable
a = 12
b = 13

sum = a + b
print(sum)
# Out:
# 25

# %%
print(12 + 13)
# Out:
# 25

# %% [markdown]
# ## Arithmetic Expressions
# - An expression that output a number using
#     - Numerical Literals
#     - Numerical Variables
#     - Arithmetics Operators

# %%
# number literal
12
# Out:
# 12

# %%
# variable
a = 12

# %%
a
# Out:
# 12

# %%
# operator
a = 12
b = 13
((a + b) / 5) + a
# Out:
# 17.0

# %% [markdown]
# ## how print() works
# - print(expression)

# %%
# printing string exrpession.
print("Hello")
# Out:
# Hello

# %% [markdown]
# ## Boolean Expression

# %%
# Boolean Literal
False
# Out:
# False

# %%
# Variable
bool_var = True

# %%
bool_var
# Out:
# True

# %%
# Comparison Operators
a = 20
a > 30
a == 20
# Out:
# True

# %%
# Logical Operators (and, or, not)
print(a == 20)
print(a > 30)
print(a == 20 and a > 30)
# Out:
# True
# False
# False

# %% [markdown]
# ## String Expression

# %%
# String literal
"Hello"
# Out:
# 'Hello'

# %%
str = "Hello"

# %%
str
# Out:
# 'Hello'

# %%
"Hello " + "How are you"
# Out:
# 'Hello How are you'

# %%
"Hello " * 3
# Out:
# 'Hello Hello Hello '

# %% [markdown]
# ## How Operators works
#
# ### Arithmetics Operators
# - arithmetics_expressions + arithmetics_expressions.
#
# ### Comparison Operators
# - expression > expression
#
# ### Logical Operators
# - boolean_expression and boolean_expression

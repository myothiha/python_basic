# %% [markdown]
# ## Variable

# %%
x = 5
y = "Python"
z = 3.14

# %%
print(x)
print(y)
print(z)
# Out:
# 5
# Python
# 3.14

# %%
x = "I\"m myo."

print(x)
# Out:
# I"m myo.

# %%
type(z)
# Out:
# float

# %%
a = b = c = 100

# %%
print(a, b, c)
# Out:
# 100 100 100

# %% [markdown]
# ## List
# - list_var[index]
# - list_var[start_index:end_index]

# %%
list_var = [0, 1, 2, 3, 4, 5, "Hello", "How are you"]
print(list_var)
# Out:
# [0, 1, 2, 3, 4, 5, 'Hello', 'How are you']

# %%
student_grades = [11, 12, 13, 14]
print(student_grades)
# Out:
# [11, 12, 13, 14]

# %%
list_var[6:]
# Out:
# ['Hello', 'How are you']

# %%
print(list_var)
# Out:
# [0, 1, 2, 3, 4, 5, 'Hello', 'How are you']

# %%
# append
list_var.append(6)
list_var.append(6)
print(list_var)
# Out:
# [0, 1, 2, 3, 4, 5, 'Hello', 'How are you', 6, 6]

# %% [markdown]
# ### Update list.

# %%
list_var[3] = 6

# %%
print(list_var)
# Out:
# [0, 1, 2, 6, 4, 5, 'Hello', 'How are you', 6, 6]

# %%
list_var.remove(6)
list_var
# Out:
# [0, 1, 2, 4, 5, 'Hello', 'How are you', 6, 6]

# %%
list_var.remove(4)
list_var
# Out:
# [0, 1, 2, 5, 'Hello', 'How are you', 6, 6]

# %%
list_var.remove(2)
list_var
# Out:
# [0, 1, 5, 'Hello', 'How are you', 6, 6]

# %%
del list_var[3]
print(list_var)
# Out:
# [0, 1, 5, 'How are you', 6, 6]

# %%
del list_var[3]
print(list_var)
# Out:
# [0, 1, 5, 6, 6]

# %%
print(list_var[3])
# Out:
# 6

# %%
print(list_var[7])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 print(list_var[7])
#
# IndexError: list index out of range

# %%
len(list_var)
# Out:
# 5

# %% [markdown]
# ## Tuple

# %%
tuple_var = (1, 1, 1, 2, 3, 4, 5)

print(tuple_var)
# Out:
# (1, 1, 1, 2, 3, 4, 5)

# %%
print(tuple_var[1])
# Out:
# 2

# %%
print(tuple_var[1:])
# Out:
# (2, 3, 4, 5)

# %%
tuple_var[2] = 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 tuple_var[2] = 7
#
# TypeError: 'tuple' object does not support item assignment

# %%
del tuple_var[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 del tuple_var[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
tuple_var.append(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 tuple_var.append(6)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tuple_list = list(tuple_var)
print(tuple_list)
# Out:
# [1, 1, 1, 2, 3, 4, 5]

# %%
tuple_list[4] = 7
print(tuple_list)
# Out:
# [1, 1, 1, 2, 7, 4, 5]

# %%
tuple_var = tuple(tuple_list)
print(tuple_var)
# Out:
# (1, 1, 1, 2, 7, 4, 5)

# %%
student_grades = [11, 12, 13, 14]

# %%
# student_grade
0: 11
1: 12
2: 13
3: 14

# %% [markdown]
# ## Dictionary
# - key value pair
# - no order

# %%
student1 = ["Mark", 25, "Business", "1A"]
# student1
# 0: "Mark"
# 1: 25
# 2: "Business"
# 3: "1A"

# %%
# age of Student 1
print(student1[1])
# Out:
# 25

# %%
student1 = {
    "name": "Mark",
    "age": 25,
    "program": "Business",
    "class": "1A"
}

# student1
# name: "Mark"
# age: 25
# program: "Business"
# class: "1A"

# %%
# age of Student 1
print(student1["age"])
# Out:
# 25

# %%
student1["age"]
# Out:
# 25

# %%
print(f"His name is {student1['name']} and he is {student1['age']} years old.")
# Out:
# His name is Mark and he is 25 years old.

# %%
dict_var2 = {"name": "Honey", "age": 14}

# %%
print(dict_var2)
# Out:
# {'name': 'Honey', 'age': 14}

# %%
del dict_var2['age']

# %%
print(dict_var2)
# Out:
# {'name': 'Honey'}

# %%
dict_var2['age'] = 25

# %%
print(dict_var2)
# Out:
# {'name': 'Honey', 'age': 25}

# %%
dict_var2['age'] = 30

# %%
print(dict_var2)
# Out:
# {'name': 'Honey', 'age': 30}

# %%
dict_var2['education'] = 'Bachelor'

# %%
print(dict_var2)
# Out:
# {'name': 'Honey', 'age': 30, 'education': 'Bachelor'}

# %%
students = [
    {
        "name": "Mark",
        "age": 25,
        "program": "Business",
        "class": "1A"
    },
    {
        "name": "Honey",
        "age": 14,
        "program": "Science",
        "class": "2B"
    },
    {
        "name": "John",
        "age": 22,
        "program": "Arts",
        "class": "3C"
    }
]

# %%
students[0]["name"]
# Out:
# 'Mark'

# %% [markdown]
# ## Set
# - no duplicate value.
# - no order.
# - no index.

# %%
set_var = {'Hello', 'How are you', 'Apple', 1, 1, 1, 1, 2, 3, 4, 5}

# %%
print(set_var)
# Out:
# {1, 2, 3, 4, 5, 'How are you', 'Apple', 'Hello'}

# %%
set_var.add(6)
print(set_var)
# Out:
# {1, 2, 3, 4, 5, 6, 'How are you', 'Apple', 'Hello'}

# %%
ait_schools = ["SET", "SERD", "SOM", "SET"]
print(ait_schools)
# Out:
# ['SET', 'SERD', 'SOM', 'SET']

# %%
ait_schools = set(ait_schools)
ait_schools = list(ait_schools)
print(ait_schools)
# Out:
# ['SERD', 'SOM', 'SET']

# %% [markdown]
# # Transversing lists, dictionaries, tuples, and sets

# %%
students_email = [
    "mark@example.com",
    "honey@example.com",
    "john@example.com",
    "alice@example.com",
    "bob@example.com"
]

# %%
students_email[0]
print("Send 'Hello' email to ", students_email[0])
# Out:
# Send 'Hello' email to  mark@example.com

# %%
for email in students_email:
    print("Send 'Hello' email to ", email)
# Out:
# Send 'Hello' email to  mark@example.com
# Send 'Hello' email to  honey@example.com
# Send 'Hello' email to  john@example.com
# Send 'Hello' email to  alice@example.com
# Send 'Hello' email to  bob@example.com

# %%
student1 = {
    "name": "Mark",
    "age": 25,
    "program": "Business",
    "class": "1A"
}

for key, value in student1.items():
    print(key, ":", value)
# Out:
# name : Mark
# age : 25
# program : Business
# class : 1A

# %%
students = [
    {"name": "Mark", "age": 25, "program": "Business", "class": "1A", "school": "SET"},
    {"name": "Honey", "age": 14, "program": "Science", "class": "1B", "school": "SERD"},
    {"name": "John", "age": 22, "program": "Arts", "class": "1C", "school": "SOM"},
    {"name": "Alice", "age": 23, "program": "Engineering", "class": "1D", "school": "SET"},
    {"name": "Bob", "age": 24, "program": "Law", "class": "1E", "school": "SERD"},
    {"name": "Charlie", "age": 26, "program": "Medicine", "class": "1F", "school": "SOM"}
]

# %%
schools = []
for single_student in students:
    schools.append(single_student["school"])

# %%
print(schools)
# Out:
# ['SET', 'SERD', 'SOM', 'SET', 'SERD', 'SOM']

# %%
schools = set(schools)
print(schools)
# Out:
# {'SERD', 'SOM', 'SET'}

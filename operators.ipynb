# %%
a = True
b = True
c = True
d = True

# %%
a = 251
b = 100

# %%
a / b
# Out:
# 2.51

# %%
a // b # round down
# Out:
# 2

# %%
round(2.51) # round off
# Out:
# 3

# %%
import math

# round up
print(math.ceil(2.1))
print(math.ceil(2.3))
print(math.ceil(2.9))
# Out:
# 3
# 3
# 3

# %%
# round down
print(math.floor(2.1))
print(math.floor(2.3))
print(math.floor(2.9))
# Out:
# 2
# 2
# 2

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ### Comparing Lists

# %%
list_a = [1, 2, 3, 10000, 100000]
list_b = [1, 2, 4, 5, 6]

# %%
list_a < list_b
# Out:
# True

# %% [markdown]
# ### Compare Strings

# %%
string_a = "["
string_b = "a"

# %%
"[" < "a"
# Out:
# True
